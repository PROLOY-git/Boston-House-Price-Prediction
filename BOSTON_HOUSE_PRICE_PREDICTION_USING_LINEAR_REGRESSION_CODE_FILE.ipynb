# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.getcwd()
# Out:
# 'C:\\Users\\PROLOY'

# %%
os.listdir()
# Out:
# ['.anaconda',
#  '.android',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.matplotlib',
#  '.nbi',
#  '.vscode',
#  'AICTE-VOIS DATA ANALYSIS',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'Assignment – Python Basic Constructs.ipynb',
#  'bank-additional-full_final (1).csv',
#  'bank-direct-marketing-campaigns.csv',
#  'bike-sharing-demand.csv',
#  'Boston_Housing_Dataset.csv',
#  'cars_handson.csv',
#  'Car_sales.csv',
#  'Churn.csv',
#  'Churndata .ipynb',
#  'Class_12_Seaborn_rajid.ipynb',
#  'CNN_CIFAR_10 (2) (1).ipynb',
#  'Contacts',
#  'Cookies',
#  'country_profile_variables (1).csv',
#  'Decision_Trees_17Mar_APC.ipynb',
#  'Decision_Trees_30Mar_APC.ipynb',
#  'Decision_Tree_APC.ipynb',
#  'Deep Learning.ipynb',
#  'Diabetes Prediction System .ipynb',
#  'Diabetes Prediction.ipynb',
#  'diabetes.csv',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'Final_model.pkl',
# ...

# %%
df_boston = pd.read_csv('Boston_Housing_Dataset.csv')

# %%
df_boston.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
#
#      TAX  PTRATIO       B  LSTAT  PRICE
# 0  296.0     15.3  396.90   4.98   24.0
# 1  242.0     17.8  396.90   9.14   21.6
# 2  242.0     17.8  392.83   4.03   34.7
# 3  222.0     18.7  394.63   2.94   33.4
# 4  222.0     18.7  396.90   5.33   36.2

# %%
df_boston.sample(4)
# Out:
#      Unnamed: 0      CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS   RAD  \
# 426         426  12.24720  0.0  18.10   0.0  0.584  5.837  59.7  1.9976  24.0
# 105         105   0.13262  0.0   8.56   0.0  0.520  5.851  96.7  2.1069   5.0
# 221         221   0.40771  0.0   6.20   1.0  0.507  6.164  91.3  3.0480   8.0
# 46           46   0.18836  0.0   6.91   0.0  0.448  5.786  33.3  5.1004   3.0
#
#        TAX  PTRATIO       B  LSTAT  PRICE
# 426  666.0     20.2   24.65  15.69   10.2
# 105  384.0     20.9  394.05  16.47   19.5
# 221  307.0     17.4  395.24  21.46   21.7
# 46   233.0     17.9  396.90  14.15   20.0

# %%
df_boston.columns
# Out:
# Index(['Unnamed: 0', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'PRICE'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
df_boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   CRIM        506 non-null    float64
#  2   ZN          506 non-null    float64
#  3   INDUS       506 non-null    float64
#  4   CHAS        506 non-null    float64
#  5   NOX         506 non-null    float64
#  6   RM          506 non-null    float64
#  7   AGE         506 non-null    float64
#  8   DIS         506 non-null    float64
#  9   RAD         506 non-null    float64
#  10  TAX         506 non-null    float64
#  11  PTRATIO     506 non-null    float64
#  12  B           506 non-null    float64
#  13  LSTAT       506 non-null    float64
#  14  PRICE       506 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 59.4 KB

# %%
df_boston.isna().sum()
# Out:
# Unnamed: 0    0
# CRIM          0
# ZN            0
# INDUS         0
# CHAS          0
# NOX           0
# RM            0
# AGE           0
# DIS           0
# RAD           0
# TAX           0
# PTRATIO       0
# B             0
# LSTAT         0
# PRICE         0
# dtype: int64

# %%
plt.subplots(figsize = (5,5))
sns.histplot(df_boston['PRICE'],bins = 10, kde = True)
plt.show()

# %%
select_house_more_than_45k = df_boston['PRICE']>45

# %%
df_boston[select_house_more_than_45k]
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS     NOX     RM    AGE     DIS  \
# 161         161  1.46336   0.0  19.58   0.0  0.6050  7.489   90.8  1.9709
# 162         162  1.83377   0.0  19.58   1.0  0.6050  7.802   98.2  2.0407
# 163         163  1.51902   0.0  19.58   1.0  0.6050  8.375   93.9  2.1620
# 166         166  2.01019   0.0  19.58   0.0  0.6050  7.929   96.2  2.0459
# 186         186  0.05602   0.0   2.46   0.0  0.4880  7.831   53.6  3.1992
# 195         195  0.01381  80.0   0.46   0.0  0.4220  7.875   32.0  5.6484
# 203         203  0.03510  95.0   2.68   0.0  0.4161  7.853   33.2  5.1180
# 204         204  0.02009  95.0   2.68   0.0  0.4161  8.034   31.9  5.1180
# 225         225  0.52693   0.0   6.20   0.0  0.5040  8.725   83.0  2.8944
# 228         228  0.29819   0.0   6.20   0.0  0.5040  7.686   17.0  3.3751
# 233         233  0.33147   0.0   6.20   0.0  0.5070  8.247   70.4  3.6519
# 257         257  0.61154  20.0   3.97   0.0  0.6470  8.704   86.9  1.8010
# ...

# %%
df_boston[select_house_more_than_45k]['RM'].mean()
# Out:
# 7.608772727272726

# %% [markdown]
# # Corelation and Coefficient

# %%
plt.figure(figsize=(15,5))
sns.heatmap(df_boston.corr(),cmap = 'Blues', annot = True, fmt = '.2%')
plt.show()

# %% [markdown]
# # Simple Linear Regression Model

# %%
x = df_boston['RM']

# %%
x
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
y = df_boston['PRICE']

# %%
y
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: PRICE, Length: 506, dtype: float64

# %%
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # ML models need data in array format for one Dimension- Only X

# %%
X = np.array(x).reshape(-1,1)### The -1 in reshape(-1, 1) tells NumPy to automatically calculate the number of rows needed based on the total number of elements in the array

# %%
X
# Out:
# array([[6.575],
#        [6.421],
#        [7.185],
#        [6.998],
#        [7.147],
#        [6.43 ],
#        [6.012],
#        [6.172],
#        [5.631],
#        [6.004],
#        [6.377],
#        [6.009],
#        [5.889],
#        [5.949],
#        [6.096],
#        [5.834],
#        [5.935],
#        [5.99 ],
#        [5.456],
#        [5.727],
#        [5.57 ],
#        [5.965],
#        [6.142],
#        [5.813],
#        [5.924],
#        [5.599],
#        [5.813],
#        [6.047],
#        [6.495],
#        [6.674],
#        [5.713],
#        [6.072],
#        [5.95 ],
#        [5.701],
#        [6.096],
#        [5.933],
#        [5.841],
#        [5.85 ],
#        [5.966],
#        [6.595],
#        [7.024],
#        [6.77 ],
#        [6.169],
#        [6.211],
#        [6.069],
#        [5.682],
#        [5.786],
#        [6.03 ],
#        [5.399],
#        [5.602],
#        [5.963],
#        [6.115],
#        [6.511],
#        [5.998],
#        [5.888],
# ...

# %%
Y = np.array(y).reshape(-1,1)  ###The -1 in reshape(-1, 1) tells NumPy to automatically calculate the number of rows needed based on the total number of elements in the array

# %%
Y
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.7],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %% [markdown]
# # Spliting the Data with 80% and 20% Ratio between X and Y

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X,Y, random_state=5, test_size = 0.20, train_size=0.80 )

# %%
X_train.mean()
# Out:
# 6.288455445544555

# %%
X_train.shape
# Out:
# (404, 1)

# %%
X_val.shape
# Out:
# (102, 1)

# %%
Y_train.shape
# Out:
# (404, 1)

# %%
Y_val.shape
# Out:
# (102, 1)

# %%
slrm = LinearRegression()

# %%
slrm
# Out:
# LinearRegression()

# %%
slrm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = slrm.predict(X_val)

# %%
y_pred
# Out:
# array([[38.10145909],
#        [25.66038564],
#        [23.78098944],
#        [10.44874691],
#        [35.02207282],
#        [13.96048253],
#        [28.71330154],
#        [26.50743745],
#        [26.41037943],
#        [23.95745857],
#        [32.59562233],
#        [19.9692563 ],
#        [19.85455137],
#        [31.00740019],
#        [24.84862766],
#        [19.2016156 ],
#        [ 7.99582605],
#        [14.84282817],
#        [14.71929978],
#        [17.95750826],
#        [12.09873325],
#        [23.38393391],
#        [40.09556022],
#        [23.47216847],
#        [29.70152865],
#        [18.81338352],
#        [23.41922773],
#        [21.65453646],
#        [22.88982035],
#        [25.21038937],
#        [18.83103043],
#        [14.93106273],
#        [19.10455758],
#        [32.39268283],
#        [24.46921904],
#        [22.97805492],
#        [25.6692091 ],
#        [19.18396869],
#        [41.26025646],
#        [29.13682744],
#        [21.80453522],
# ...

# %%
Y_val
# Out:
# array([[37.6],
#        [27.9],
#        [22.6],
#        [13.8],
#        [35.2],
#        [10.4],
#        [23.9],
#        [29. ],
#        [22.8],
#        [23.2],
#        [33.2],
#        [19. ],
#        [20.3],
#        [36.1],
#        [24.4],
#        [17.2],
#        [17.9],
#        [19.6],
#        [19.7],
#        [15. ],
#        [ 8.1],
#        [23. ],
#        [44.8],
#        [23.1],
#        [32.2],
#        [10.8],
#        [23.1],
#        [21.2],
#        [22.2],
#        [24.1],
#        [17.3],
#        [ 7. ],
#        [12.7],
#        [17.8],
#        [26.4],
#        [19.6],
#        [25.1],
#        [ 8.3],
#        [48.8],
#        [34.9],
#        [13.8],
#        [14.4],
#        [30.1],
#        [12.7],
#        [27.1],
#        [24.8],
#        [ 7. ],
#        [20.5],
#        [21.5],
#        [14. ],
#        [20.4],
#        [22.2],
#        [21.4],
#        [13.5],
#        [19.4],
#        [24.7],
#        [43.8],
#        [14.1],
# ...

# %%
mse = mean_squared_error(y_pred, Y_val)

# %%
mse
# Out:
# 23.97045552799131

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 4.895963186952217

# %%
y.min()
# Out:
# 5.0

# %%
y.max()
# Out:
# 50.0

# %%
y.mean()
# Out:
# 22.532806324110677

# %%
error = (rmse/y.mean())*100

# %%
error
# Out:
# 21.728155457109715

# %%
Accuracy = 100 - error

# %%
Accuracy
# Out:
# 78.27184454289028

# %% [markdown]
# # R-Square

# %%
r_square = slrm.score(X_val,Y_val)

# %%
r_square
# Out:
# 0.6938399401553497

# %%
r_square*100
# Out:
# 69.38399401553497

# %%
df_boston
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO       B  LSTAT  PRICE
# ...

# %%
x1 = df_boston[['RM','LSTAT','CRIM']]

# %%
x1
# Out:
#         RM  LSTAT     CRIM
# 0    6.575   4.98  0.00632
# 1    6.421   9.14  0.02731
# 2    7.185   4.03  0.02729
# 3    6.998   2.94  0.03237
# 4    7.147   5.33  0.06905
# ..     ...    ...      ...
# 501  6.593   9.67  0.06263
# 502  6.120   9.08  0.04527
# 503  6.976   5.64  0.06076
# 504  6.794   6.48  0.10959
# 505  6.030   7.88  0.04741
#
# [506 rows x 3 columns]

# %%
y1 = df_boston['PRICE']

# %%
X=np.array(x1).reshape(-1,3)

# %%
X
# Out:
# array([[6.5750e+00, 4.9800e+00, 6.3200e-03],
#        [6.4210e+00, 9.1400e+00, 2.7310e-02],
#        [7.1850e+00, 4.0300e+00, 2.7290e-02],
#        ...,
#        [6.9760e+00, 5.6400e+00, 6.0760e-02],
#        [6.7940e+00, 6.4800e+00, 1.0959e-01],
#        [6.0300e+00, 7.8800e+00, 4.7410e-02]])

# %%
Y = np.array(y1).reshape(-1,1)

# %%
Y
# Out:
# array([[24. ],
#        [21.6],
#        [34.7],
#        [33.4],
#        [36.2],
#        [28.7],
#        [22.9],
#        [27.1],
#        [16.5],
#        [18.9],
#        [15. ],
#        [18.9],
#        [21.7],
#        [20.4],
#        [18.2],
#        [19.9],
#        [23.1],
#        [17.5],
#        [20.2],
#        [18.2],
#        [13.6],
#        [19.6],
#        [15.2],
#        [14.5],
#        [15.6],
#        [13.9],
#        [16.6],
#        [14.8],
#        [18.4],
#        [21. ],
#        [12.7],
#        [14.5],
#        [13.2],
#        [13.1],
#        [13.5],
#        [18.9],
#        [20. ],
#        [21. ],
#        [24.7],
#        [30.8],
#        [34.9],
#        [26.6],
#        [25.3],
#        [24.7],
#        [21.2],
#        [19.3],
#        [20. ],
#        [16.6],
#        [14.4],
#        [19.4],
#        [19.7],
#        [20.5],
#        [25. ],
#        [23.4],
#        [18.9],
#        [35.4],
#        [24.7],
#        [31.6],
# ...

# %%
X_train1,X_val1,Y_train1,Y_val1 = train_test_split(X,Y,test_size=0.20,train_size=0.80,random_state=5)

# %%
X_train1.shape
# Out:
# (404, 3)

# %%
X_val1.shape
# Out:
# (102, 3)

# %%
Y_train1.shape
# Out:
# (404, 1)

# %%
Y_val1.shape
# Out:
# (102, 1)

# %%
slrm = LinearRegression()

# %%
slrm
# Out:
# LinearRegression()

# %%
slrm.fit(X_train1,Y_train1)
# Out:
# LinearRegression()

# %%
y_pred = slrm.predict(X_val1)

# %%
y_pred
# Out:
# array([[37.37251472],
#        [29.68168343],
#        [26.00709087],
#        [ 0.83267249],
#        [33.49589618],
#        [ 6.40120195],
#        [30.71782975],
#        [27.92687822],
#        [26.546297  ],
#        [22.1341912 ],
#        [32.45559495],
#        [23.34801289],
#        [23.10580094],
#        [31.12134961],
#        [27.27468133],
#        [21.03720193],
#        [-1.0559263 ],
#        [18.13743646],
#        [13.11380378],
#        [16.55841359],
#        [ 6.18269598],
#        [24.23999886],
#        [37.80191808],
#        [24.79950215],
#        [29.82644824],
#        [12.26911222],
#        [27.0528506 ],
#        [22.76072467],
#        [27.55125748],
#        [28.92307668],
#        [12.58391117],
#        [11.40816316],
#        [17.1808698 ],
#        [24.6442842 ],
#        [26.46407865],
#        [23.21885147],
#        [26.50272499],
#        [11.75363282],
#        [37.2630161 ],
#        [33.31755927],
#        [19.90549556],
# ...

# %%
Y_val1
# Out:
# array([[37.6],
#        [27.9],
#        [22.6],
#        [13.8],
#        [35.2],
#        [10.4],
#        [23.9],
#        [29. ],
#        [22.8],
#        [23.2],
#        [33.2],
#        [19. ],
#        [20.3],
#        [36.1],
#        [24.4],
#        [17.2],
#        [17.9],
#        [19.6],
#        [19.7],
#        [15. ],
#        [ 8.1],
#        [23. ],
#        [44.8],
#        [23.1],
#        [32.2],
#        [10.8],
#        [23.1],
#        [21.2],
#        [22.2],
#        [24.1],
#        [17.3],
#        [ 7. ],
#        [12.7],
#        [17.8],
#        [26.4],
#        [19.6],
#        [25.1],
#        [ 8.3],
#        [48.8],
#        [34.9],
#        [13.8],
#        [14.4],
#        [30.1],
#        [12.7],
#        [27.1],
#        [24.8],
#        [ 7. ],
#        [20.5],
#        [21.5],
#        [14. ],
#        [20.4],
#        [22.2],
#        [21.4],
#        [13.5],
#        [19.4],
#        [24.7],
#        [43.8],
#        [14.1],
# ...

# %%
mse = mean_squared_error(y_pred, Y_val1)

# %%
mse
# Out:
# 25.91752991941747

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 5.090926233939897

# %%
y.mean()
# Out:
# 22.532806324110677

# %%
error = (rmse/y.mean())*100

# %%
error
# Out:
# 22.593396316074827

# %% [markdown]
# ACCURACY

# %%
Accuracy = 100 - error

# %%
Accuracy
# Out:
# 77.40660368392517

# %%
r2_score = slrm.score(X_val1,Y_val1)

# %%
r2_score
# Out:
# 0.6689711423344276
